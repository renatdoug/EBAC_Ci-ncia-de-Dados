# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

#np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
# 1)Seu código aqui
print(f'Matemática: {(df_mat["Qt_acertos"].sum() / (24 * 100)):.2%}')
print(f'Português: {(df_por["Qt_acertos"].sum() / (18 * 100)):.2%}')
print(f'Geografia: {(df_geo["Qt_acertos"].sum() / (8 * 100)):.2%}')
print(f'Inglês: {(df_ing["Qt_acertos"].sum() / (8 * 100)):.2%}')
print(f'História: {(df_his["Qt_acertos"].sum() / (8 * 100)):.2%}')
print(f'Física: {(df_fis["Qt_acertos"].sum() / (12 * 100)):.2%}')
print(f'Química: {(df_qui["Qt_acertos"].sum() / (12 * 100)):.2%}')
# Out:
# Matemática: 49.17%
# Português: 46.39%
# Geografia: 41.00%
# Inglês: 45.50%
# História: 43.88%
# Física: 50.08%
# Química: 50.33%

# %%
# 2) Seu código aqui

df['Matemática'] = df_mat["Qt_acertos"]
df['Português'] = df_por["Qt_acertos"]
df['Geografia'] = df_geo["Qt_acertos"]
df['Inglês'] = df_ing["Qt_acertos"]
df['História'] = df_his["Qt_acertos"]
df['Física'] = df_fis["Qt_acertos"]
df['Química'] = df_qui["Qt_acertos"]
df['Total_Acertos'] = (df['Matemática'] + df['Português'] + 
                       df['Geografia'] + df['Inglês'] + 
                       df['História'] + df['Física'] + 
                       df['Química'])
df.head(100)
# Out:
#     Matemática  Português  Geografia  Inglês  História  Física  Química  \
# 0           23          9          1       5         4       4       11
# 1           13          5          7       4         7       0        7
# 2           15         16          0       5         4      10        4
# 3           12         10          7       6         5       0        6
# 4           14          3          2       4         4      10        9
# ..         ...        ...        ...     ...       ...     ...      ...
# 95           3         14          3       7         4      11        0
# 96           4          3          7       4         4       7        4
# 97          19          5          3       2         2       8        9
# 98          22          4          3       6         2       0        8
# 99           1          3          3       1         7       8       10
#
#     Total_Acertos  Total_Acertos_%
# 0              57            63.33
# ...

# %%
# 3) Seu código aqui
Qt_acertos_total = 24 + 18 + 8 + 8 + 8 + 12 + 12

df['Total_Acertos_%'] = round((df['Total_Acertos'] / Qt_acertos_total * 100), 2)
df.head(10)
# Out:
#    Matemática  Português  Geografia  Inglês  História  Física  Química  \
# 0          23          9          1       5         4       4       11
# 1          13          5          7       4         7       0        7
# 2          15         16          0       5         4      10        4
# 3          12         10          7       6         5       0        6
# 4          14          3          2       4         4      10        9
# 5           2         11          1       3         6       8        0
# 6          13         11          6       0         5       4        5
# 7          18          8          3       3         2       4        6
# 8          16         12          3       7         1       8        8
# 9          22          1          6       2         4       7        7
#
#    Total_Acertos  Total_Acertos_%
# 0             57            63.33
# 1             43            47.78
# 2             54            60.00
# 3             46            51.11
# ...

# %%
# 4) Seu código aqui
df[df['Total_Acertos'] > 45].index.nunique()
# Out:
# 42

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
# seu código aqui
df_eliminados = df[ (df['Matemática'] == 0) |
                         (df['Física'] == 0) |
                         (df['Química'] == 0) ]

df_eliminados.head(10)
# Out:
#     Matemática  Português  Geografia  Inglês  História  Física  Química  \
# 1           13          5          7       4         7       0        7
# 3           12         10          7       6         5       0        6
# 5            2         11          1       3         6       8        0
# 11          10          7          7       7         7      11        0
# 14           2         15          7       0         3       7        0
# 15           2         11          4       4         0       0        0
# 16           0          2          7       5         2       2        6
# 21           2          0          1       6         5       3        0
# 26           5         11          3       3         0       0        7
# 31          11          6          1       6         1       0        3
#
#     Total_Acertos  Total_Acertos_%
# 1              43            47.78
# 3              46            51.11
# 5              31            34.44
# ...

# %%
# 2. Quantos são esses alunos?
df_eliminados.index.nunique()
# Out:
# 22

# %%
# 3. Qual a média desses alunos em história e geografia?
print(f'Média História: {df_eliminados["História"].mean():.2}')
print(f'Média Geografia: {df_eliminados["Geografia"].mean():.2}')
# Out:
# Média História: 3.5
# Média Geografia: 3.8

# %%
# 4. Monte um DataFrame com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

df_qualificados = df[ (df['Matemática'] != 0) &
                         (df['Física'] != 0) &
                         (df['Química'] != 0) ]
df_qualificados
# Out:
#     Matemática  Português  Geografia  Inglês  História  Física  Química  \
# 0           23          9          1       5         4       4       11
# 2           15         16          0       5         4      10        4
# 4           14          3          2       4         4      10        9
# 6           13         11          6       0         5       4        5
# 7           18          8          3       3         2       4        6
# ..         ...        ...        ...     ...       ...     ...      ...
# 92           2         10          1       0         6       3        2
# 93          10         10          0       7         7       3       11
# 96           4          3          7       4         4       7        4
# 97          19          5          3       2         2       8        9
# 99           1          3          3       1         7       8       10
#
#     Total_Acertos  Total_Acertos_%
# 0              57            63.33
# ...

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
arquivo = 'https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-05-23/uf%3DAC/part-00000-63e5bee2-3684-4286-b709-7fe85483b04e.c000.csv'

# %%
vacAcre = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')
vacAcre.head(5)
# Out:
#                                  document_id  \
# 0  b19cd280-474c-4c22-a35d-8c06bc04a4e0-i0b0
# 1  a1acc0b6-1cf6-4c4b-adcb-06b473a0faaf-i0b0
# 2  af279a98-ba1f-47ea-8214-314a98040b0d-i0b0
# 3  4879308e-5050-46bb-b8e2-11fa5646a05c-i0b0
# 4  000e911b-e3a4-4114-a735-d1f2e6e3797f-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  2e091c9a37d3f50d1d705fc80c6448c6fc69b44da9e936...              69
# 1  f4e17a9e5354cb45e223d85eda02fb2f76048c801675f5...              81
# 2  6734b26bccf826130ebffa66575977bbe71477b12bcf42...              69
# 3  84a341fd350c1ba7117fccbb4d2df417bc0fac0fffac37...              51
# 4  c59571e19f368d4b0cf08cd3bcabb32e5cd8baad5340f6...              65
#
#   paciente_datanascimento paciente_enumsexobiologico  paciente_racacor_codigo  \
# 0              1951-12-28                          F                        3
# 1              1939-11-22                          M                        3
# ...

# %%
# 1) Sua solução aqui
print(f'Estão registradas {vacAcre.shape[0]} vacinas')
# Out:
# Estão registradas 169071 vacinas

# %%
#2) Quantidade de pacientes vacinados
pac = vacAcre['paciente_id'].nunique()
print(f'Foram vacinados {pac} pacientes')
# Out:
# Foram vacinados 120517 pacientes

# %%
#3 Quantos pacientes únicos tomaram a primeira dose? 
primeira_dose = vacAcre[vacAcre['vacina_descricao_dose'] == '\xa0\xa0\xa0\xa01ª\xa0Dose']
pd = len(primeira_dose)
print(f'{pd} pacientes únicos tomaram a primeira dose')
# Out:
# 120939 pacientes únicos tomaram a primeira dose

# %%
# 4) Quantos pacientes com menos de 18 anos foram vacinados
df_menor = vacAcre[vacAcre["paciente_idade"]<18]
df_menor = df_menor['paciente_id'].nunique()
print(f'{df_menor} pacientes com menos de 18 anos forma vacinados')
# Out:
# 47 pacientes com menos de 18 anos forma vacinados

# %%
# 5) Quantos estabelecimentos aplicaram vacina no Acre?
estab = vacAcre['estabelecimento_razaosocial'].nunique()
print(f'{estab} establecimentos aplicaram vacina no Acre')
# Out:
# 42 establecimentos aplicaram vacina no Acre

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# 1) 
#df_menor4 = df_menor[df_menor["paciente_idade"]<18]
df_menor = vacAcre[vacAcre["paciente_idade"]<18].copy()
df_menor.head(5)
# Out:
#                                      document_id  \
# 1567   fdca313f-b348-422d-94d4-f2c66a87868c-i0b0
# 6250   b7431955-1faa-4c1e-9246-7c1e7b8bb3cb-i0b0
# 9569   fdb8d3b6-14d9-4bcc-9cfe-acd46b4a317a-i0b0
# 11338  647e2301-3ba4-463a-8d1e-2b6f38a4d99e-i0b0
# 15144  7f469e03-bece-49d0-bebc-33ad98e27f54-i0b0
#
#                                              paciente_id  paciente_idade  \
# 1567   f5e6b8c44f7c4d13a87c582def5e8d460435b02f26af8c...              17
# 6250   e1a45c07e3c393d5f0eccf4204a7ceab338f4f06696ecb...              16
# 9569   7cf3b238383a70eeb26841c01817737c9706d5b231e8c2...              17
# 11338  53eb7fed5faa26ad17ce21ee378f28e25399ab7e90bc05...              17
# 15144  dbaa6420d8a815158387668d0a59a19cf2bb63958e35d1...              16
#
#       paciente_datanascimento paciente_enumsexobiologico  \
# 1567               2003-07-18                          F
# 6250               2004-05-18                          M
# ...

# %%
# 2) crie uma lista das colunas desse DataFrame com o atributo de DataFrame .co
lista_colunas = list(df_menor.columns)
lista_colunas
# Out:
# ['document_id',
#  'paciente_id',
#  'paciente_idade',
#  'paciente_datanascimento',
#  'paciente_enumsexobiologico',
#  'paciente_racacor_codigo',
#  'paciente_racacor_valor',
#  'paciente_endereco_coibgemunicipio',
#  'paciente_endereco_copais',
#  'paciente_endereco_nmmunicipio',
#  'paciente_endereco_nmpais',
#  'paciente_endereco_uf',
#  'paciente_endereco_cep',
#  'paciente_nacionalidade_enumnacionalidade',
#  'estabelecimento_valor',
#  'estabelecimento_razaosocial',
#  'estalecimento_nofantasia',
#  'estabelecimento_municipio_codigo',
#  'estabelecimento_municipio_nome',
#  'estabelecimento_uf',
#  'vacina_grupoatendimento_codigo',
#  'vacina_grupoatendimento_nome',
#  'vacina_categoria_codigo',
#  'vacina_categoria_nome',
#  'vacina_lote',
#  'vacina_fabricante_nome',
#  'vacina_fabricante_referencia',
#  'vacina_dataaplicacao',
#  'vacina_descricao_dose',
#  'vacina_codigo',
#  'vacina_nome',
#  'sistema_origem',
#  'data_importacao_rnds',
#  'id_sistema_origem']

# %%
# 3) Nesse DataFrame faça uma contagem do campo vacina_categoria_nome.
df_menor['vacina_categoria_nome'].value_counts()
# Out:
# Povos Indígenas                     33
# Trabalhadores de Saúde               9
# Povos e Comunidades Tradicionais     9
# Comorbidades                         2
# Faixa Etária                         1
# Name: vacina_categoria_nome, dtype: int64

# %%
# 4) a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, 
#    faça uma lista com esses valores
lista_estabelecimento = []
for i in lista_colunas:
    # Achei um erro de digitacao em uma coluna
    if 'esta' in i and 'cimento' in i:
        lista_estabelecimento.append(i)
lista_estabelecimento
# Out:
# ['estabelecimento_valor',
#  'estabelecimento_razaosocial',
#  'estalecimento_nofantasia',
#  'estabelecimento_municipio_codigo',
#  'estabelecimento_municipio_nome',
#  'estabelecimento_uf']

# %%
# 4) a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, 
#    faça uma lista com esses valores
list((df_menor.loc[df_menor['paciente_idade'] < 18, lista_estabelecimento]).drop_duplicates())
# Out:
# ['estabelecimento_valor',
#  'estabelecimento_razaosocial',
#  'estalecimento_nofantasia',
#  'estabelecimento_municipio_codigo',
#  'estabelecimento_municipio_nome',
#  'estabelecimento_uf']

# %%
# 5)usando o método .loc, selecione somente essas variáveis
df2 = df_menor.loc[df_menor['paciente_idade'] < 18, lista_estabelecimento]
df2
# Out:
#         estabelecimento_valor  \
# 1567                  2001314
# 6250                  6917291
# 9569                  6159087
# 11338                 2000040
# 15144                 7625855
# 17153                 6748759
# 18361                 6308740
# 18608                 2001748
# 20204                 6917682
# 20759                 6917291
# 21119                 6428940
# 27860                 7625855
# 29127                 6612385
# 31200                 7625855
# 35654                 6159087
# 38412                 6159087
# 51872                 2000040
# 57405                 9648968
# 61131                 6430201
# 62742                 6917291
# 66922                 7625855
# 68290                 6955525
# 69882                 5336171
# 70881                 6697151
# 75368                 6748759
# 78289                 6430201
# 79146                 2001748
# 81424                 6955525
# 84331                 2001748
# 88619                 6430201
# ...

# %%
#6)Aplique o método .drop_duplicates e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento
df2.drop_duplicates()
# Out:
#         estabelecimento_valor  \
# 1567                  2001314
# 6250                  6917291
# 9569                  6159087
# 11338                 2000040
# 15144                 7625855
# 17153                 6748759
# 18361                 6308740
# 18608                 2001748
# 20204                 6917682
# 21119                 6428940
# 29127                 6612385
# 57405                 9648968
# 61131                 6430201
# 68290                 6955525
# 69882                 5336171
# 70881                 6697151
# 101402                3323307
# 140895                7123043
#
#                               estabelecimento_razaosocial  \
# 1567               PREFEITURA MUNICIPAL DE EPITACIOLANDIA
# 6250                   PREFEITURA MUNICIPAL DE RIO BRANCO
# 9569              PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 11338                       PREFEITURA MUNICIPAL DE FEIJO
# 15144   DISTRITO SANITARIO ESPECIAL INDIGENA ALTO RIO ...
# ...
